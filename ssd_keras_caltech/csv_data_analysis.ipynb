# %%
import pandas as pd

# %%
#df = pd.read_csv("labels_trainval_full.csv")
#df = pd.read_csv("labels_train.csv")
#df = pd.read_csv("labels_val.csv")
df = pd.read_csv("labels_test_full.csv")

# %%
df
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  occl
# 0        set06_V000_187.png   184   194   186   211         3     0
# 1        set06_V000_187.png   202   207   191   215         3     0
# 2        set06_V000_176.png   176   186   187   212         3     0
# 3        set06_V000_176.png   194   199   191   215         3     0
# 4        set06_V000_113.png   171   180   183   209         3     0
# 5        set06_V000_113.png   189   196   187   211         3     0
# 6        set06_V000_147.png   171   180   183   209         3     0
# 7        set06_V000_147.png   189   195   189   212         3     0
# 8        set06_V000_886.png    20    39   153   214         1     1
# 9        set06_V000_310.png   159   164   198   231         3     0
# 10       set06_V000_310.png     2    20   184   291         1     1
# 11        set06_V000_57.png   171   180   183   209         3     0
# 12        set06_V000_57.png   188   196   187   211         3     0
# ...

# %%
df.index
#RangeIndex(start=0, stop=153234, step=1)
#RangeIndex(start=0, stop=79831, step=1) case 2
# Out:
# RangeIndex(start=0, stop=154436, step=1)

# %%
df_no_occl = df[df['occl'] == 0]

# %%
df_no_occl
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  occl
# 0        set06_V000_187.png   184   194   186   211         3     0
# 1        set06_V000_187.png   202   207   191   215         3     0
# 2        set06_V000_176.png   176   186   187   212         3     0
# 3        set06_V000_176.png   194   199   191   215         3     0
# 4        set06_V000_113.png   171   180   183   209         3     0
# 5        set06_V000_113.png   189   196   187   211         3     0
# 6        set06_V000_147.png   171   180   183   209         3     0
# 7        set06_V000_147.png   189   195   189   212         3     0
# 9        set06_V000_310.png   159   164   198   231         3     0
# 11        set06_V000_57.png   171   180   183   209         3     0
# 12        set06_V000_57.png   188   196   187   211         3     0
# 13       set06_V000_263.png   183   196   189   219         3     0
# 14       set06_V000_263.png   208   213   193   222         3     0
# ...

# %%
df_per = df_no_occl[df_no_occl['class_id'] == 1]

# %%
df_per.index
# Out:
# Int64Index([    20,     25,     37,     40,     55,     56,     72,     79,
#                 83,     85,
#             ...
#             154425, 154426, 154427, 154428, 154429, 154430, 154431, 154433,
#             154434, 154435],
#            dtype='int64', length=73218)

# %%
df = df_per

# %%
image_set = {}
image_set = set(df['frame'])
len(image_set)
# Out:
# 42910

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id', 'occl'], dtype='object')

# %%
df['height'] = df['ymax'] -  df['ymin']
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['width'] = df['xmax'] -  df['xmin']
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_with_height = df[(df['height'] >= 50) == True]

# %%
df_with_proper_height_width = df_with_height[(df_with_height['width'] >= 5) == True]

# %%
df_with_proper_height_width['aspect'] = df_with_proper_height_width['width']/ df_with_proper_height_width['height']
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_with_proper_height_width['aspect']
# Out:
# 28        0.380000
# 31        0.442308
# 47        0.403846
# 75        0.368421
# 80        0.403846
# 94        0.442308
# 113       0.372549
# 122       0.383333
# 141       0.480000
# 146       0.384615
# 153       0.410714
# 224       0.490566
# 245       0.500000
# 254       0.362069
# 264       0.377358
# 296       0.540000
# 306       0.461538
# 313       0.377358
# 324       0.423077
# 353       0.355932
# 354       0.461538
# 435       0.540000
# 436       0.355932
# 441       0.369231
# 447       0.442308
# 491       0.384615
# 503       0.365385
# 517       0.423077
# 553       0.380282
# 573       0.355932
#             ...
# 192067    0.232472
# 192069    0.214744
# 192071    0.396552
# 192075    0.323944
# 192078    0.338843
# 192080    0.229927
# 192082    0.303681
# 192087    0.401813
# 192088    0.362500
# 192092    0.396825
# 192096    0.320000
# 192099    0.325581
# 192104    0.541176
# 192108    0.548387
# 192109    0.227273
# 192115    0.391304
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#values = [153234, 34950, 1153, 2848]
#plt.hist(df.class_id, num_bins, histtype='bar', color='b', edgecolor='r')
x_pos = np.arange(0, 1, 0.1)

#df = pd.read_csv("labels_trainval.csv")

plt.figure(figsize=(20,10))
plt.xlabel('Pedestrian aspect ratio')
plt.ylabel('Number of samples in the dataset')
plt.title(r'Histogram of Pedestrian aspect ratio')
# Create names
plt.xticks(x_pos, x_pos)

plt.hist(df_with_proper_height_width['aspect'],density=0, bins=100) 

#plt.savefig("aspect_ratio_distribution.png")
plt.show()

# %%
df = df_with_proper_height_width.drop(['width', 'height'], axis=1)

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id', 'occl'], dtype='object')

# %%
df
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  occl
# 20       set06_V000_276.png    58    92   179   260         1     0
# 25       set06_V000_287.png    39    75   180   269         1     0
# 37       set06_V000_297.png    11    51   186   279         1     0
# 40       set06_V000_271.png    67    98   179   253         1     0
# 83       set06_V000_306.png     3    27   184   290         1     0
# 85       set06_V000_284.png    44    80   180   267         1     0
# 109      set06_V000_290.png    32    69   180   271         1     0
# 128      set06_V000_270.png    69    99   179   250         1     0
# 133      set06_V000_295.png    14    56   184   277         1     0
# 154      set06_V000_275.png    60    94   180   259         1     0
# 162      set06_V000_305.png     4    30   184   288         1     0
# 246      set06_V000_277.png    57    93   179   261         1     0
# 264      set06_V000_281.png    50    85   179   264         1     0
# ...

# %%
df.to_csv("labels_test.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#values = [153234, 34950, 1153, 2848]
#plt.hist(df.class_id, num_bins, histtype='bar', color='b', edgecolor='r')
x_pos = np.arange(1, len(classes) + 1)

df = pd.read_csv("labels_trainval.csv")

plt.figure(figsize=(20,10))
plt.xlabel('Pedestrian Classes')
plt.ylabel('Number of samples in the dataset')
plt.title(r'Histogram of Pedestrian Classes')
# Create names
plt.xticks(x_pos, classes)

plt.hist(df.class_id,density=0, bins=4) 

plt.savefig("classid_distribution.png")
plt.show()

# %%
plt.savefig("classid_distribution.png")
