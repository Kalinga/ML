# %%
import pandas as pd

# %%
df = pd.read_csv("labels_trainval_full.csv")
#df = pd.read_csv("labels_train.csv")
#df = pd.read_csv("labels_val.csv")

# %%
df
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  occl
# 0       set00_V000_1184.png   534   551   170   204         1     0
# 1       set00_V000_1184.png   503   520   167   203         2     0
# 2       set00_V000_1184.png    78    87    98   118         2     1
# 3       set00_V000_1682.png   359   378   118   144         2     1
# 4       set00_V000_1682.png   331   346   127   142         2     1
# 5       set00_V000_1682.png   525   544   155   197         1     0
# 6       set00_V000_1682.png   243   257   127   145         2     1
# 7       set00_V000_1682.png   410   424   167   189         1     0
# 8       set00_V000_1768.png   354   378   116   140         2     1
# 9       set00_V000_1768.png   294   316   119   141         2     1
# 10      set00_V000_1768.png   382   396   119   141         2     1
# 11      set00_V000_1768.png   187   199   123   141         2     1
# 12      set00_V000_1768.png   455   473   174   212         1     1
# 13      set00_V000_1329.png   584   603   131   177         1     0
# 14       set00_V000_637.png   375   386   166   184         2     0
# 15      set00_V000_1786.png   353   377   111   135         2     1
# 16      set00_V000_1786.png   294   316   119   141         2     1
# 17      set00_V000_1786.png   380   393   116   137         2     1
# 18      set00_V000_1786.png   173   186   121   140         2     1
# 19      set00_V000_1786.png   481   500   170   220         1     1
# 20       set00_V000_316.png   499   566   148   197         2     0
# 21       set00_V000_316.png   211   226    42    69         1     0
# 22       set00_V000_316.png   518   540    55    83         2     1
# 23      set00_V000_1652.png   366   381   129   148         2     1
# 24      set00_V000_1652.png   339   353   135   149         2     1
# 25      set00_V000_1652.png   260   275   130   148         2     1
# 26      set00_V000_1652.png   398   411   169   191         1     0
# 27      set00_V000_1575.png   448   469   168   193         1     0
# 28      set00_V000_1575.png   500   519   156   206         1     0
# 29      set00_V000_1575.png   546   612   149   200         2     0
# ...                     ...   ...   ...   ...   ...       ...   ...
# 192155   set05_V012_345.png   363   380   158   196         1     1
# 192156   set05_V012_713.png   382   551    68   479         1     1
# 192157   set05_V012_713.png   500   624   117   479         1     1
# 192158   set05_V012_379.png   293   319   152   217         1     0
# 192159   set05_V012_379.png   261   280   166   190         2     0
# 192160   set05_V012_379.png   356   374   154   209         1     1
# 192161   set05_V012_379.png   342   361   155   209         1     1
# 192162  set05_V012_1137.png   278   291   204   222         1     0
# 192163   set05_V012_261.png   354   368   146   176         1     0
# 192164   set05_V012_391.png   284   311   151   219         1     0
# 192165   set05_V012_391.png   241   260   167   191         2     0
# 192166   set05_V012_391.png   351   369   153   213         1     1
# 192167   set05_V012_391.png   335   355   153   213         1     1
# 192168  set05_V012_1218.png   291   304   203   221         1     0
# 192169   set05_V012_285.png   351   367   146   179         1     0
# 192170   set05_V012_746.png     0   107    83   469         1     1
# 192171   set05_V012_746.png   111   291   108   469         1     1
# 192172  set05_V012_1132.png   277   289   204   222         1     0
# 192173   set05_V012_359.png   313   337   153   213         1     0
# 192174   set05_V012_359.png   298   317   165   189         2     0
# 192175   set05_V012_359.png   366   385   155   204         1     1
# 192176   set05_V012_359.png   355   372   158   202         1     1
# 192177   set05_V012_396.png   281   308   151   220         1     0
# 192178   set05_V012_396.png   234   253   167   191         2     0
# 192179   set05_V012_396.png   354   374   152   215         1     1
# 192180   set05_V012_396.png   337   357   152   213         1     1
# 192181   set05_V012_378.png   294   320   152   216         1     0
# 192182   set05_V012_378.png   263   282   166   190         2     0
# 192183   set05_V012_378.png   356   374   154   209         1     1
# 192184   set05_V012_378.png   342   361   155   209         1     1
#
# [192185 rows x 7 columns]

# %%
df.index
#RangeIndex(start=0, stop=153234, step=1)
#RangeIndex(start=0, stop=79831, step=1) case 2
# Out:
# RangeIndex(start=0, stop=153234, step=1)

# %%
df_no_occl = df[df['occl'] == 0]

# %%
df_per = df_no_occl[df_no_occl['class_id'] == 1]

# %%
df_per.index
# Out:
# Int64Index([     0,      5,      7,     13,     21,     26,     27,     28,
#                 30,     31,
#             ...
#             192158, 192162, 192163, 192164, 192168, 192169, 192172, 192173,
#             192177, 192181],
#            dtype='int64', length=93629)

# %%
df = df_per

# %%
image_set = {}
image_set = set(df['frame'])
len(image_set)
# Out:
# 46838

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id', 'occl'], dtype='object')

# %%
df['height'] = df['ymax'] -  df['ymin']
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['width'] = df['xmax'] -  df['xmin']
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_with_height = df[(df['height'] >= 50) == True]

# %%
df_with_proper_height_width = df_with_height[(df_with_height['width'] >= 5) == True]

# %%
df_with_proper_height_width
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  occl  height  \
# 28      set00_V000_1575.png   500   519   156   206         1     0      50
# 31       set00_V000_372.png   515   538   152   204         1     0      52
# 47       set00_V000_382.png   542   563   153   205         1     0      52
# 75      set00_V000_1592.png   535   556   154   211         1     0      57
# 80      set00_V000_1720.png   614   635   155   207         1     0      52
# 94       set00_V000_369.png   508   531   152   204         1     0      52
# 113      set00_V000_397.png   600   619   155   206         1     0      51
# 122      set00_V000_736.png   545   568   154   214         1     0      60
# 141      set00_V000_416.png   542   566   152   202         1     0      50
# 146     set00_V000_1721.png   618   638   155   207         1     0      52
# 153      set00_V000_431.png   596   619   152   208         1     0      56
# 224      set00_V000_423.png   564   590   151   204         1     0      53
# 245     set00_V000_1712.png   585   610   152   202         1     0      50
# 254     set00_V000_1597.png   548   569   155   213         1     0      58
# 264     set00_V000_1581.png   511   531   154   207         1     0      53
# 296      set00_V000_545.png   606   633   156   206         1     0      50
# 306      set00_V000_367.png   504   528   152   204         1     0      52
# 313     set00_V000_1579.png   507   527   155   208         1     0      53
# 324      set00_V000_374.png   519   541   152   204         1     0      52
# 353      set00_V000_284.png   531   552   154   213         1     0      59
# 354      set00_V000_284.png   578   602   159   211         1     0      52
# 435      set00_V000_539.png   588   615   154   204         1     0      50
# 436     set00_V000_1604.png   569   590   157   216         1     0      59
# 441      set00_V000_745.png   567   591   153   218         1     0      65
# 447      set00_V000_714.png   502   525   155   207         1     0      52
# 491     set00_V000_1578.png   505   525   155   207         1     0      52
# 503     set00_V000_1577.png   503   522   155   207         1     0      52
# 517      set00_V000_375.png   522   544   153   205         1     0      52
# 553      set00_V000_756.png   595   622   151   222         1     0      71
# 573     set00_V000_1602.png   563   584   157   216         1     0      59
# ...                     ...   ...   ...   ...   ...       ...   ...     ...
# 192067   set05_V012_528.png   515   578   103   374         1     0     271
# 192069   set05_V012_541.png   555   622    90   402         1     0     312
# 192071   set05_V012_354.png   319   342   153   211         1     0      58
# 192075   set05_V012_469.png   383   429   146   288         1     0     142
# 192078   set05_V012_469.png   479   520   148   269         1     0     121
# 192080   set05_V012_529.png   518   581   102   376         1     0     274
# 192082  set05_V012_1064.png   541   640   132   458         1     0     326
# 192087  set05_V012_1058.png   495   628   128   459         1     0     331
# 192088   set05_V012_409.png   285   314   148   228         1     0      80
# 192092   set05_V012_373.png   298   323   152   215         1     0      63
# 192096   set05_V012_475.png   395   443   144   294         1     0     150
# 192099   set05_V012_475.png   498   540   148   277         1     0     129
# 192104  set05_V012_1018.png    69   253   126   466         1     0     340
# 192108  set05_V012_1019.png    77   264   126   467         1     0     341
# 192109   set05_V012_533.png   530   595    98   384         1     0     286
# 192115   set05_V012_395.png   282   309   151   220         1     0      69
# 192120  set05_V012_1051.png   406   579   129   457         1     0     328
# 192121   set05_V012_453.png   352   391   147   269         1     0     122
# 192124   set05_V012_453.png   440   474   149   255         1     0     106
# 192125  set05_V012_1024.png   123   318   126   468         1     0     342
# 192127   set05_V012_543.png   561   628    87   406         1     0     319
# 192131   set05_V012_411.png   286   316   148   230         1     0      82
# 192139   set05_V012_362.png   310   334   153   213         1     0      60
# 192147   set05_V012_377.png   295   321   152   216         1     0      64
# 192152   set05_V012_345.png   328   351   152   206         1     0      54
# 192158   set05_V012_379.png   293   319   152   217         1     0      65
# 192164   set05_V012_391.png   284   311   151   219         1     0      68
# 192173   set05_V012_359.png   313   337   153   213         1     0      60
# 192177   set05_V012_396.png   281   308   151   220         1     0      69
# 192181   set05_V012_378.png   294   320   152   216         1     0      64
#
#         width
# 28         19
# 31         23
# 47         21
# 75         21
# 80         21
# 94         23
# 113        19
# 122        23
# 141        24
# 146        20
# 153        23
# 224        26
# 245        25
# 254        21
# 264        20
# 296        27
# 306        24
# 313        20
# 324        22
# 353        21
# 354        24
# 435        27
# 436        21
# 441        24
# 447        23
# 491        20
# 503        19
# 517        22
# 553        27
# 573        21
# ...       ...
# 192067     63
# 192069     67
# 192071     23
# 192075     46
# 192078     41
# 192080     63
# 192082     99
# 192087    133
# 192088     29
# 192092     25
# 192096     48
# 192099     42
# 192104    184
# 192108    187
# 192109     65
# 192115     27
# 192120    173
# 192121     39
# 192124     34
# 192125    195
# 192127     67
# 192131     30
# 192139     24
# 192147     26
# 192152     23
# 192158     26
# 192164     27
# 192173     24
# 192177     27
# 192181     26
#
# [48194 rows x 9 columns]

# %%
df = df_with_proper_height_width.drop(['width', 'height'], axis=1)

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id', 'occl'], dtype='object')

# %%
df.to_csv("labels_trainval.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#values = [153234, 34950, 1153, 2848]
#plt.hist(df.class_id, num_bins, histtype='bar', color='b', edgecolor='r')
x_pos = np.arange(1, len(classes) + 1)

df = pd.read_csv("labels_trainval.csv")

plt.figure(figsize=(20,10))
plt.xlabel('Pedestrian Classes')
plt.ylabel('Number of samples in the dataset')
plt.title(r'Histogram of Pedestrian Classes')
# Create names
plt.xticks(x_pos, classes)

plt.hist(df.class_id,density=0, bins=4) 

plt.savefig("classid_distribution.png")
plt.show()

# %%
plt.savefig("classid_distribution.png")
