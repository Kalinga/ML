# %%
import pandas as pd

# %%
df = pd.read_csv("labels_trainval.csv")
#df = pd.read_csv("labels_train.csv")
#df = pd.read_csv("labels_val.csv")

# %%
df
# Out:
#                      frame  xmin  xmax  ymin  ymax  class_id
# 0       set00_V000_744.png   564   588   153   218         1
# 1       set00_V000_740.png   554   578   153   215         1
# 2      set00_V000_1585.png   519   539   154   209         1
# 3       set00_V000_285.png   533   554   154   213         1
# 4       set00_V000_285.png   582   606   159   211         1
# 5       set00_V000_285.png   562   580   159   209         1
# 6       set00_V000_376.png   525   547   153   205         1
# 7       set00_V000_396.png   596   615   155   206         1
# 8       set00_V000_418.png   548   573   152   203         1
# 9       set00_V000_714.png   502   525   155   207         1
# 10      set00_V000_367.png   504   528   152   204         1
# 11      set00_V000_365.png   501   525   151   203         1
# 12      set00_V000_724.png   521   544   154   210         1
# 13     set00_V000_1592.png   535   556   154   211         1
# 14      set00_V000_293.png   618   638   159   211         1
# 15      set00_V000_293.png   584   602   158   221         1
# 16      set00_V000_473.png   611   633   133   184         1
# 17      set00_V000_725.png   523   546   154   210         1
# 18      set00_V000_432.png   601   623   152   208         1
# 19     set00_V000_1716.png   598   621   153   204         1
# 20     set00_V000_1801.png   510   529   173   226         1
# 21     set00_V000_1579.png   507   527   155   208         1
# 22     set00_V000_1600.png   557   578   156   215         1
# 23      set00_V000_731.png   535   558   154   212         1
# 24     set00_V000_1609.png   589   613   156   222         1
# 25     set00_V000_1790.png   487   506   170   225         1
# 26      set00_V000_276.png   510   529   157   208         1
# 27      set00_V000_276.png   550   573   158   208         1
# 28      set00_V000_380.png   536   557   153   205         1
# 29      set00_V000_375.png   522   544   153   205         1
# ...                    ...   ...   ...   ...   ...       ...
# 79801   set05_V012_717.png   311   484    65   478         1
# 79802   set05_V012_717.png   457   600   117   480         1
# 79803   set05_V012_668.png   341   537    63   478         1
# 79804  set05_V012_1043.png   325   495   131   458         1
# 79805   set05_V012_379.png   293   319   152   217         1
# 79806   set05_V012_379.png   356   374   154   209         1
# 79807   set05_V012_379.png   342   361   155   209         1
# 79808   set05_V012_709.png   443   635    73   479         1
# 79809   set05_V012_709.png   539   636   119   479         1
# 79810   set05_V012_360.png   312   336   153   213         1
# 79811  set05_V012_1014.png    36   180   129   466         1
# 79812   set05_V012_370.png   301   326   153   215         1
# 79813   set05_V012_370.png   361   379   155   207         1
# 79814   set05_V012_370.png   348   366   156   206         1
# 79815  set05_V012_1060.png   503   633   128   459         1
# 79816   set05_V012_412.png   287   317   147   230         1
# 79817   set05_V012_412.png   365   391   150   222         1
# 79818   set05_V012_412.png   344   367   149   222         1
# 79819   set05_V012_421.png   295   326   147   237         1
# 79820   set05_V012_421.png   384   413   149   230         1
# 79821   set05_V012_421.png   357   381   149   222         1
# 79822  set05_V012_1057.png   490   625   128   459         1
# 79823  set05_V012_1047.png   361   540   130   457         1
# 79824   set05_V012_414.png   288   318   147   231         1
# 79825   set05_V012_414.png   368   395   149   223         1
# 79826   set05_V012_414.png   345   367   149   213         1
# 79827  set05_V012_1019.png    77   264   126   467         1
# 79828   set05_V012_507.png   464   521   122   336         1
# 79829   set05_V012_745.png     0   126    83   469         1
# 79830   set05_V012_745.png   125   305   108   469         1
#
# [79831 rows x 6 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=79831, step=1)

# %%
image_set = {}
image_set = set(df['frame'])
len(image_set)
# Out:
# 37081

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], dtype='object')

# %%
df['height'] = df['ymax'] -  df['ymin']

# %%
df['width'] = df['xmax'] -  df['xmin']

# %%
df_with_height = df[(df['height'] >= 50) == True]

# %%
df_with_proper_height_width = df_with_height[(df_with_height['width'] >= 10) == True]

# %%
df_with_proper_height_width
# Out:
#                       frame  xmin  xmax  ymin  ymax  class_id  height  width
# 5        set00_V000_744.png   564   588   153   218         1      65     24
# 8        set00_V000_740.png   554   578   153   215         1      62     24
# 15      set00_V000_1585.png   519   539   154   209         1      55     20
# 18       set00_V000_285.png   533   554   154   213         1      59     21
# 19       set00_V000_285.png   582   606   159   211         1      52     24
# 20       set00_V000_285.png   562   580   159   209         1      50     18
# 32       set00_V000_376.png   525   547   153   205         1      52     22
# 38       set00_V000_396.png   596   615   155   206         1      51     19
# 45       set00_V000_418.png   548   573   152   203         1      51     25
# 60       set00_V000_714.png   502   525   155   207         1      52     23
# 63       set00_V000_367.png   504   528   152   204         1      52     24
# 71       set00_V000_365.png   501   525   151   203         1      52     24
# 96       set00_V000_724.png   521   544   154   210         1      56     23
# 111     set00_V000_1592.png   535   556   154   211         1      57     21
# 152      set00_V000_293.png   618   638   159   211         1      52     20
# 153      set00_V000_293.png   584   602   158   221         1      63     18
# 156      set00_V000_473.png   611   633   133   184         1      51     22
# 158      set00_V000_725.png   523   546   154   210         1      56     23
# 164      set00_V000_432.png   601   623   152   208         1      56     22
# 177     set00_V000_1716.png   598   621   153   204         1      51     23
# 179     set00_V000_1801.png   510   529   173   226         1      53     19
# 183     set00_V000_1579.png   507   527   155   208         1      53     20
# 192     set00_V000_1600.png   557   578   156   215         1      59     21
# 195      set00_V000_731.png   535   558   154   212         1      58     23
# 198     set00_V000_1609.png   589   613   156   222         1      66     24
# 200     set00_V000_1790.png   487   506   170   225         1      55     19
# 203      set00_V000_276.png   510   529   157   208         1      51     19
# 204      set00_V000_276.png   550   573   158   208         1      50     23
# 211      set00_V000_380.png   536   557   153   205         1      52     21
# 234      set00_V000_375.png   522   544   153   205         1      52     22
# ...                     ...   ...   ...   ...   ...       ...     ...    ...
# 153193   set05_V012_717.png   311   484    65   478         1     413    173
# 153194   set05_V012_717.png   457   600   117   480         1     363    143
# 153195   set05_V012_668.png   341   537    63   478         1     415    196
# 153197  set05_V012_1043.png   325   495   131   458         1     327    170
# 153198   set05_V012_379.png   293   319   152   217         1      65     26
# 153199   set05_V012_379.png   356   374   154   209         1      55     18
# 153200   set05_V012_379.png   342   361   155   209         1      54     19
# 153203   set05_V012_709.png   443   635    73   479         1     406    192
# 153204   set05_V012_709.png   539   636   119   479         1     360     97
# 153205   set05_V012_360.png   312   336   153   213         1      60     24
# 153208  set05_V012_1014.png    36   180   129   466         1     337    144
# 153210   set05_V012_370.png   301   326   153   215         1      62     25
# 153211   set05_V012_370.png   361   379   155   207         1      52     18
# 153212   set05_V012_370.png   348   366   156   206         1      50     18
# 153213  set05_V012_1060.png   503   633   128   459         1     331    130
# 153216   set05_V012_412.png   287   317   147   230         1      83     30
# 153217   set05_V012_412.png   365   391   150   222         1      72     26
# 153218   set05_V012_412.png   344   367   149   222         1      73     23
# 153219   set05_V012_421.png   295   326   147   237         1      90     31
# 153220   set05_V012_421.png   384   413   149   230         1      81     29
# 153221   set05_V012_421.png   357   381   149   222         1      73     24
# 153223  set05_V012_1057.png   490   625   128   459         1     331    135
# 153224  set05_V012_1047.png   361   540   130   457         1     327    179
# 153226   set05_V012_414.png   288   318   147   231         1      84     30
# 153227   set05_V012_414.png   368   395   149   223         1      74     27
# 153228   set05_V012_414.png   345   367   149   213         1      64     22
# 153229  set05_V012_1019.png    77   264   126   467         1     341    187
# 153230   set05_V012_507.png   464   521   122   336         1     214     57
# 153232   set05_V012_745.png     0   126    83   469         1     386    126
# 153233   set05_V012_745.png   125   305   108   469         1     361    180
#
# [79831 rows x 8 columns]

# %%
df = df_with_proper_height_width.drop(['width', 'height'], axis=1)

# %%
df.columns
# Out:
# Index(['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], dtype='object')

# %%
df.to_csv("labels_trainval.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#values = [153234, 34950, 1153, 2848]
#plt.hist(df.class_id, num_bins, histtype='bar', color='b', edgecolor='r')
x_pos = np.arange(1, len(classes) + 1)

df = pd.read_csv("labels_trainval.csv")

plt.figure(figsize=(20,10))
plt.xlabel('Pedestrian Classes')
plt.ylabel('Number of samples in the dataset')
plt.title(r'Histogram of Pedestrian Classes')
# Create names
plt.xticks(x_pos, classes)

plt.hist(df.class_id,density=0, bins=4) 

plt.savefig("classid_distribution.png")
plt.show()

# %%
plt.savefig("classid_distribution.png")
