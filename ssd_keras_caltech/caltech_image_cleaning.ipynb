# %%
from PIL import Image
import cv2

img = Image.open('/home/kara9147/ML/caltech-pedestrian-dataset-converter/data/images/set05_V010_942.png')
print("(width, height){}".format(img.size))
w, h = img.size
print (w, h)
# Out:
# (width, height)(640, 480)
# 640 480

# %%
from os import listdir
from os.path import isfile, join

img_path = '/home/kara9147/ML/caltech-pedestrian-dataset-converter/data/images/'
img_files = [f for f in listdir(img_path) if isfile(join(img_path, f))]

# %%
import cv2

for i in range(4):
    print(img_files[i])
    img = im = cv2.imread(img_path + img_files[i])
    print(img.shape)
# Out:
# set10_V007_1262.png
# (480, 640, 3)
# set01_V002_977.png
# (480, 640, 3)
# set00_V000_1076.png
# (480, 640, 3)
# set05_V008_404.png
# (480, 640, 3)

# %%
print("Total image file {}".format(len(img_files)))
for f in img_files:
    img = cv2.imread(img_path + img_files[i])
    # shape. It returns a tuple of number of rows, columns and channels (if image is color):
    h, w, c = img.shape
    assert w == 640, "{} Width is not 640".format(img_path + img_files[i])
    assert h == 480, "{} Height is not 480".format(img_path + img_files[i])
    assert c == 3,   "{} Channel is not 3".format(img_path + img_files[i])
# Out:
# Total image file 249895
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c71d4899275d> in <module>
#       2 print("Total image file {}".format(len(img_files)))
#       3 for f in img_files:
# ----> 4     img = cv2.imread(img_path + img_files[i])
#       5     # shape. It returns a tuple of number of rows, columns and channels (if image is color):
#       6     h, w, c = img.shape
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20,12))
file_name =  "/home/kara9147/ML/caltech-pedestrian-dataset-converter/data/images/set05_V005_846.png"
img = cv2.imread(file_name)
print(img.shape)
#xmin,xmax,ymin,ymax,class_id
#475,499,200,235
xmin = 475 
ymin = 200 
xmax = 499 
ymax = 235
plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, color="blue", fill=False, linewidth=1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
current_axis = plt.gca()
current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, color="blue", fill=False, linewidth=1))

plt.show()
# Out:
# (480, 640, 3)
